# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as srn

# %%
df=pd.read_csv(r"C:\Users\Satish_Kundekar\Downloads\salary_prediction.csv")

# %%
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
df.shape
# Out:
# (30, 2)

# %%
df.size
# Out:
# 60

# %%
df.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
df.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
plt.scatter(df['YearsExperience'], df['Salary'])
plt.xlabel('Salary')
plt.ylabel('YearsExperience')
plt.show()

# %%
srn.boxplot(data=df['YearsExperience'])
# Out:
# <Axes: ylabel='YearsExperience'>

# %%
X=df[['YearsExperience']]

# %%
Y=df['Salary']

# %%
X
# Out:
#     YearsExperience
# 0               1.1
# 1               1.3
# 2               1.5
# 3               2.0
# 4               2.2
# 5               2.9
# 6               3.0
# 7               3.2
# 8               3.2
# 9               3.7
# 10              3.9
# 11              4.0
# 12              4.0
# 13              4.1
# 14              4.5
# 15              4.9
# 16              5.1
# 17              5.3
# 18              5.9
# 19              6.0
# 20              6.8
# 21              7.1
# 22              7.9
# 23              8.2
# 24              8.7
# 25              9.0
# 26              9.5
# 27              9.6
# 28             10.3
# 29             10.5

# %%
Y
# Out:
# 0      39343.0
# 1      46205.0
# 2      37731.0
# 3      43525.0
# 4      39891.0
# 5      56642.0
# 6      60150.0
# 7      54445.0
# 8      64445.0
# 9      57189.0
# 10     63218.0
# 11     55794.0
# 12     56957.0
# 13     57081.0
# 14     61111.0
# 15     67938.0
# 16     66029.0
# 17     83088.0
# 18     81363.0
# 19     93940.0
# 20     91738.0
# 21     98273.0
# 22    101302.0
# 23    113812.0
# 24    109431.0
# 25    105582.0
# 26    116969.0
# 27    112635.0
# 28    122391.0
# 29    121872.0
# Name: Salary, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2, random_state=11)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (24, 1)
# (6, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
lr.coef_ # m value
# Out:
# array([9504.98248109])

# %%
lr.intercept_ # c value
# Out:
# np.float64(25375.305271282858)

# %%
lr.score(X_test,Y_test)
# Out:
# 0.940882728477622

# %%
lr.predict([[12]])
# Out:
# D:\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([139435.0950444])

# %%
lr.predict([[12],[4]])
# Out:
# D:\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([139435.0950444 ,  63395.23519566])

# %%
lr.score(X_train,Y_train)
# Out:
# 0.9586469490522905

# %%
y_pred=lr.predict(X_test)

# %%
Y_test
# Out:
# 15     67938.0
# 8      64445.0
# 6      60150.0
# 26    116969.0
# 3      43525.0
# 11     55794.0
# Name: Salary, dtype: float64

# %%
result=pd.DataFrame({'Actual':Y_test,'Predicted':y_pred})

# %%
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error

# %%
mse=mean_squared_error(Y_test,y_pred)

# %%
np.sqrt(mse)  #RMSE
# Out:
# np.float64(5632.71878108415)

# %%
r2_score(Y_test,y_pred)
# Out:
# 0.940882728477622

# %%
# Model Accurnacy is 94 %

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
mean_absolute_error(Y_test,y_pred)
# Out:
# 4780.514015125237

# %%
mean_squared_error(Y_test,y_pred)
# Out:
# 31727520.866778105

# %%
np.sqrt(mse)
# Out:
# np.float64(5632.71878108415)

# %%
r2_score(Y_test,y_pred)
# Out:
# 0.940882728477622
