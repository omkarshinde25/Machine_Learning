# %%
import numpy as np

# %%
# 0D Tensor

# %%
a=np.array(4)

# %%
print(a)
# Out:
# 4

# %%
a # 0 D Tensor
# Out:
# array(4)

# %%
a.ndim # ndim = no of dimentional
# Out:
# 0

# %%
# 1D Tensor | Vectors

# %%
arr=np.array([1,2,3,4])

# %%
print(arr)
# Out:
# [1 2 3 4]

# %%
arr # 1 D Tensor and 4D Vector
# Out:
# array([1, 2, 3, 4])

# %%
arr.ndim
# Out:
# 1

# %%
# 2D Tensor | Matrices

# %%
# matrices is collection of the vectors

# %%
mat = np.array([[1,2,3],[2,3,4],[4,5,6]])

# %%
print(mat)
# Out:
# [[1 2 3]
#  [2 3 4]
#  [4 5 6]]

# %%
mat
# Out:
# array([[1, 2, 3],
#        [2, 3, 4],
#        [4, 5, 6]])

# %%
mat.ndim
# Out:
# 2

# %%
# !pip install jupyter_contrib_nbextensions
# Out:
# ...
#      ---------------------------------------- 0.0/23.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/23.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/23.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/23.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/23.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/23.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/23.5 MB ? eta -:--:--
#      ---------------------------------------- 0.3/23.5 MB ? eta -:--:--
#      ---------------------------------------- 0.3/23.5 MB ? eta -:--:--
#       -------------------------------------- 0.5/23.5 MB 541.0 kB/s eta 0:00:43
#       -------------------------------------- 0.5/23.5 MB 541.0 kB/s eta 0:00:43
#      - ------------------------------------- 0.8/23.5 MB 556.4 kB/s eta 0:00:41
#      - ------------------------------------- 0.8/23.5 MB 556.4 kB/s eta 0:00:41
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
